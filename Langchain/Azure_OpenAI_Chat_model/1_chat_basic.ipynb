# %%
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: langchain-openai in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from -r ../requirements.txt (line 1)) (0.2.11)
# Collecting python-dotenv==1.0.1 (from -r ../requirements.txt (line 2))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting langchain (from -r ../requirements.txt (line 3))
#   Downloading langchain-0.3.9-py3-none-any.whl.metadata (7.1 kB)
# Collecting wikipedia==1.4.0 (from -r ../requirements.txt (line 4))
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tavily-python (from -r ../requirements.txt (line 5))
#   Downloading tavily_python-0.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting sentence-transformers (from -r ../requirements.txt (line 6))
#   Downloading sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from -r ../requirements.txt (line 7)) (4.67.1)
# Collecting firecrawl-py (from -r ../requirements.txt (line 8))
#   Downloading firecrawl_py-1.6.3-py3-none-any.whl.metadata (10 kB)
# Collecting langchain_community (from -r ../requirements.txt (line 9))
#   Downloading langchain_community-0.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from wikipedia==1.4.0->-r ../requirements.txt (line 4)) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from wikipedia==1.4.0->-r ../requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from langchain-openai->-r ../requirements.txt (line 1)) (0.3.21)
# Requirement already satisfied: openai<2.0.0,>=1.54.0 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from langchain-openai->-r ../requirements.txt (line 1)) (1.56.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from langchain-openai->-r ../requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from langchain->-r ../requirements.txt (line 3)) (6.0.2)
# Collecting SQLAlchemy<3,>=1.4 (from langchain->-r ../requirements.txt (line 3))
#   Downloading SQLAlchemy-2.0.36-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.7 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain->-r ../requirements.txt (line 3))
#   Downloading aiohttp-3.11.10-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain->-r ../requirements.txt (line 3))
#   Downloading langchain_text_splitters-0.3.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from langchain->-r ../requirements.txt (line 3)) (0.1.147)
# Collecting numpy<3,>=1.26.2 (from langchain->-r ../requirements.txt (line 3))
#   Downloading numpy-2.1.3-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from langchain->-r ../requirements.txt (line 3)) (2.10.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from langchain->-r ../requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: httpx in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from tavily-python->-r ../requirements.txt (line 5)) (0.27.0)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading transformers-4.47.0-py3-none-any.whl.metadata (43 kB)
# Collecting torch>=1.11.0 (from sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading torch-2.5.1-cp312-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Collecting scikit-learn (from sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading scikit_learn-1.5.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (13 kB)
# Collecting scipy (from sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading huggingface_hub-0.26.3-py3-none-any.whl.metadata (13 kB)
# Collecting Pillow (from sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading pillow-11.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting websockets (from firecrawl-py->-r ../requirements.txt (line 8))
#   Downloading websockets-14.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from firecrawl-py->-r ../requirements.txt (line 8)) (1.6.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community->-r ../requirements.txt (line 9))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain_community->-r ../requirements.txt (line 9))
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community->-r ../requirements.txt (line 9))
#   Downloading pydantic_settings-2.6.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 3))
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 3))
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 3)) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 3))
#   Downloading frozenlist-1.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 3))
#   Downloading multidict-6.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 3))
#   Downloading propcache-0.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain->-r ../requirements.txt (line 3))
#   Downloading yarl-1.18.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (69 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r ../requirements.txt (line 9))
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r ../requirements.txt (line 9))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting filelock (from huggingface-hub>=0.20.0->sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.20.0->sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r ../requirements.txt (line 6)) (24.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r ../requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai->-r ../requirements.txt (line 1)) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain->-r ../requirements.txt (line 3)) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain->-r ../requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from httpx->tavily-python->-r ../requirements.txt (line 5)) (4.6.2)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from httpx->tavily-python->-r ../requirements.txt (line 5)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from httpx->tavily-python->-r ../requirements.txt (line 5)) (1.0.2)
# Requirement already satisfied: idna in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from httpx->tavily-python->-r ../requirements.txt (line 5)) (3.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from httpx->tavily-python->-r ../requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from httpcore==1.*->httpx->tavily-python->-r ../requirements.txt (line 5)) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai->-r ../requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai->-r ../requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r ../requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r ../requirements.txt (line 3)) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->wikipedia==1.4.0->-r ../requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->wikipedia==1.4.0->-r ../requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai->-r ../requirements.txt (line 1)) (2024.11.6)
# Collecting networkx (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 6)) (3.1.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 6)) (75.1.0)
# Collecting sympy==1.13.1 (from torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading safetensors-0.4.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from beautifulsoup4->wikipedia==1.4.0->-r ../requirements.txt (line 4)) (2.5)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers->-r ../requirements.txt (line 6))
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain-openai->-r ../requirements.txt (line 1)) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community->-r ../requirements.txt (line 9))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/GenAI/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers->-r ../requirements.txt (line 6)) (2.1.3)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading langchain-0.3.9-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.3 MB/s eta 0:00:00
# Downloading tavily_python-0.5.0-py3-none-any.whl (14 kB)
# Downloading sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
# Downloading firecrawl_py-1.6.3-py3-none-any.whl (16 kB)
# Downloading langchain_community-0.3.9-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 54.7 MB/s eta 0:00:00
# Downloading aiohttp-3.11.10-cp312-cp312-macosx_11_0_arm64.whl (455 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading huggingface_hub-0.26.3-py3-none-any.whl (447 kB)
# Downloading langchain_text_splitters-0.3.2-py3-none-any.whl (25 kB)
# Downloading numpy-2.1.3-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 25.9 MB/s eta 0:00:00
# Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Downloading SQLAlchemy-2.0.36-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 41.1 MB/s eta 0:00:00
# Downloading torch-2.5.1-cp312-none-macosx_11_0_arm64.whl (63.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 MB 28.8 MB/s eta 0:00:00a 0:00:01
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 51.2 MB/s eta 0:00:00
# Downloading transformers-4.47.0-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 42.0 MB/s eta 0:00:00 0:00:01
# Downloading pillow-11.0.0-cp312-cp312-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 41.7 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.2-cp312-cp312-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 30.5 MB/s eta 0:00:00 0:00:01
# Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 32.6 MB/s eta 0:00:00a 0:00:01
# Downloading websockets-14.1-cp312-cp312-macosx_11_0_arm64.whl (159 kB)
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.5.0-cp312-cp312-macosx_11_0_arm64.whl (51 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
# Downloading multidict-6.1.0-cp312-cp312-macosx_11_0_arm64.whl (29 kB)
# Downloading propcache-0.2.1-cp312-cp312-macosx_11_0_arm64.whl (45 kB)
# Downloading safetensors-0.4.5-cp312-cp312-macosx_11_0_arm64.whl (381 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tokenizers-0.21.0-cp39-abi3-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 38.6 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.18.3-cp312-cp312-macosx_11_0_arm64.whl (92 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 49.0 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 26.2 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11679 sha256=baddb14059eae82fd016eaa432f40cdf92b72c3c687e83979cfc88a23693fe2d
#   Stored in directory: /Users/ankitkumarsinha/Library/Caches/pip/wheels/63/47/7c/a9688349aa74d228ce0a9023229c6c0ac52ca2a40fe87679b8
# Successfully built wikipedia
# Installing collected packages: mpmath, websockets, threadpoolctl, sympy, SQLAlchemy, safetensors, python-dotenv, propcache, Pillow, numpy, networkx, mypy-extensions, multidict, marshmallow, joblib, httpx-sse, fsspec, frozenlist, filelock, aiohappyeyeballs, yarl, wikipedia, typing-inspect, torch, scipy, huggingface-hub, firecrawl-py, aiosignal, tokenizers, tavily-python, scikit-learn, pydantic-settings, dataclasses-json, aiohttp, transformers, sentence-transformers, langchain-text-splitters, langchain, langchain_community
# Successfully installed Pillow-11.0.0 SQLAlchemy-2.0.36 aiohappyeyeballs-2.4.4 aiohttp-3.11.10 aiosignal-1.3.1 dataclasses-json-0.6.7 filelock-3.16.1 firecrawl-py-1.6.3 frozenlist-1.5.0 fsspec-2024.10.0 httpx-sse-0.4.0 huggingface-hub-0.26.3 joblib-1.4.2 langchain-0.3.9 langchain-text-splitters-0.3.2 langchain_community-0.3.9 marshmallow-3.23.1 mpmath-1.3.0 multidict-6.1.0 mypy-extensions-1.0.0 networkx-3.4.2 numpy-2.1.3 propcache-0.2.1 pydantic-settings-2.6.1 python-dotenv-1.0.1 safetensors-0.4.5 scikit-learn-1.5.2 scipy-1.14.1 sentence-transformers-3.3.1 sympy-1.13.1 tavily-python-0.5.0 threadpoolctl-3.5.0 tokenizers-0.21.0 torch-2.5.1 transformers-4.47.0 typing-inspect-0.9.0 websockets-14.1 wikipedia-1.4.0 yarl-1.18.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Load Env Variables and Secrets

# %%
import os
from dotenv import load_dotenv
load_dotenv('../../../azure.env')
os.environ["AZURE_OPENAI_API_VERSION"] = "2024-06-01"
os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"] = 'gpt-4o-mini'

# %% [markdown]
# Initialize the Model

# %%
from langchain_openai import AzureChatOpenAI

model = AzureChatOpenAI(
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    openai_api_version=os.environ["AZURE_OPENAI_API_VERSION"],
)

# %% [markdown]
# Invoke the model

# %%
# Invoke the model with a message
result = model.invoke("What is 81 divided by 9?")
print("Full result:")
print(result)
print("Content only:")
print(result.content)
# Out:
# Full result:
# content='81 divided by 9 equals 9.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 16, 'total_tokens': 25, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gpt-4o-mini', 'system_fingerprint': 'fp_04751d0b65', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'profanity': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'profanity': {'filtered': False, 'detected': False}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}} id='run-5266da11-111e-43c9-9b17-5fb2e5aae2c3-0' usage_metadata={'input_tokens': 16, 'output_tokens': 9, 'total_tokens': 25, 'input_token_details': {}, 'output_token_details': {}}
# Content only:
# 81 divided by 9 equals 9.
